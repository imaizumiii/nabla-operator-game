# %%
from sympy import *

# %%
from sympy import symbols, expand, factor, simplify, latex, solve

# %%
x,y = symbols("x y")

# %%
print(x,y)
# Out:
# x y

# %%
expr = (x+2)**2
expanded = expand(expr)
print(expanded)
# Out:
# x**2 + 4*x + 4

# %%
x,y = symbols('x y')
expr = sqrt(x)

inverse = solve(expr - y ,x)
print(inverse)
# Out:
# [y**2]

# %%
# Out:
# 1
